# %%
import numpy as np
import xarray as xr
import pandas as pd
#import metpy.calc as mpcalc
from glob import glob
import holoviews as hv
hv.extension('bokeh')
#%matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib.colors import LinearSegmentedColormap

import cartopy.crs as ccrs
import cartopy.feature as cfeature

import sys
sys.path.append('/home/vmaithel')

from tropical_PODs.PODs.POD_utils import limit_files_to_select_years

# Define constants

g = 9.8 #[m s^-2]
L = 2.26e6 #[J/kg]
cp = 1005 #[J/kg-K]
R_e = 6.378e6 #[m]
pi = 22/7
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="eec16aa2-2574-481a-a17d-db5b79b89118" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
def load_in_data(input_file, xarray_name, start_year, end_year, lat_lbound, lat_ubound):
    
    paths = glob(input_file)
    year_limited_paths = limit_files_to_select_years(paths,range(start_year,end_year+1))
    dataset = xr.open_mfdataset(year_limited_paths, combine="by_coords")
    dataset = dataset.sortby('lat', ascending=True)

    data_var = dataset[xarray_name].sel(time = slice(str(start_year)+'-01-01', str(end_year)+'-12-31'), lat = slice(lat_lbound,lat_ubound))
    data_var.load()

    return dataset, data_var

# %% [markdown]
# ### INPUT directiories and load in data

# %%
# Years to analyze
start_year = (2010)
end_year = (2011)

lat_lbound = -15 
lat_ubound = 15

################
###.  VIJIT MSE budget calculations  ###
################

input_dir = '/home/vmaithel/MSE_budgets/2p5_vijit/'

input_file_MSE = input_dir+'MSE.*.nc'
input_file_MSE_tend = input_dir+'MSE_tend.*.nc'  
input_file_col_MSE = input_dir+'col_MSE.*.nc' 
input_file_VADV = input_dir+'VADV.*.nc' 
input_file_col_VADV = input_dir+'col_VADV.*.nc' 
input_file_HADV = input_dir+'HADV.*.nc' 
input_file_col_HADV = input_dir+'col_HADV.*.nc' 
input_file_HADV_zonal = input_dir+'HADV_zonal.*.nc' 
input_file_col_HADV_zonal = input_dir+'col_HADV_zonal.*.nc' 
input_file_HADV_meridional = input_dir+'HADV_meridional.*.nc' 
input_file_col_HADV_meridional = input_dir+'col_HADV_meridional.*.nc' 
input_file_SF = input_dir+'SF.*.nc'
input_file_RadF_net = input_dir+'RadF_net.*.nc'

dataset_col_MSE, col_MSE = load_in_data(input_file_col_MSE,'col_MSE',start_year, end_year, lat_lbound, lat_ubound)
dataset_col_VADV, col_VADV = load_in_data(input_file_col_VADV,'col_VADV',start_year, end_year, lat_lbound, lat_ubound)
dataset_col_HADV, col_HADV = load_in_data(input_file_col_HADV,'col_HADV',start_year, end_year, lat_lbound, lat_ubound)
dataset_col_HADV_zonal, col_HADV_zonal = load_in_data(input_file_col_HADV_zonal,'col_HADV_zonal',start_year, end_year, lat_lbound, lat_ubound)
dataset_col_HADV_meridional, col_HADV_meridional = load_in_data(input_file_col_HADV_meridional,'col_HADV_meridional',start_year, end_year, lat_lbound, lat_ubound)
dataset_MSE_tend, MSE_tend = load_in_data(input_file_MSE_tend,'MSE_tend',start_year, end_year, lat_lbound, lat_ubound)
dataset_SF, SF = load_in_data(input_file_SF,'SF',start_year, end_year, lat_lbound, lat_ubound)
dataset_RadF_net, RadF_net = load_in_data(input_file_RadF_net,'RadF_net',start_year, end_year, lat_lbound, lat_ubound)

################
###.  JIM MSE budget calculations  ###
################

input_file_jim_col_budget = '/Projects/era5_regrid/2p5_benedict/ERA5_2.5deg_daily/ERA5.MSEviBudget.*.nc'
input_file_jim_VADV = '/Projects/era5_regrid/2p5_benedict/ERA5_2.5deg_daily/MSEvert.2p5.*.daily.nc'
input_file_jim_HADV = '/Projects/era5_regrid/2p5_benedict/ERA5_2.5deg_daily/MSEhoriz.2p5.*.daily.nc'

dataset_jim_MSE_colbgt, MSE_tend_jim = load_in_data(input_file_jim_col_budget,'viDMDT', start_year, end_year, lat_lbound, lat_ubound)
dataset_jim_MSE_colbgt, col_VADV_jim = load_in_data(input_file_jim_col_budget,'viWDMDP', start_year, end_year, lat_lbound, lat_ubound)
dataset_jim_MSE_colbgt, col_HADV_jim = load_in_data(input_file_jim_col_budget,'viVDOTDELM', start_year, end_year, lat_lbound, lat_ubound)
dataset_jim_MSE_colbgt, col_HADV_zonal_jim = load_in_data(input_file_jim_col_budget,'viUDMDX', start_year, end_year, lat_lbound, lat_ubound)
dataset_jim_MSE_colbgt, col_HADV_meridional_jim = load_in_data(input_file_jim_col_budget,'viVDMDY', start_year, end_year, lat_lbound, lat_ubound)

###### add loading in vertically resolved quantities

# %%
#### Apply land mask ####

# Land
ifile_land_frac = '/Projects/era5_regrid/2p5_vijit/ERAi_landfrac_2p5.nc' # ERAi Land Fraction

dataset_land = xr.open_dataset(ifile_land_frac)
landfrac = dataset_land['landfrac']
landfrac.load()

landfrac = landfrac.sel(lat = slice(-15, 15)) 
landfrac = landfrac.sortby('lat', ascending=True) # Re-order lat to match code for other datasets

# Create ocean mask #

is_valid_ocean_mask = (landfrac < 0.1)

col_VADV = col_VADV.where(is_valid_ocean_mask, other = np.nan)
col_VADV_jim = col_VADV_jim.where(is_valid_ocean_mask, other = np.nan)

col_HADV = col_HADV.where(is_valid_ocean_mask, other = np.nan)
col_HADV_jim = col_HADV_jim.where(is_valid_ocean_mask, other = np.nan)

MSE_tend = MSE_tend.where(is_valid_ocean_mask, other = np.nan)
MSE_tend_jim = MSE_tend_jim.where(is_valid_ocean_mask, other = np.nan)

col_HADV_zonal = col_HADV_zonal.where(is_valid_ocean_mask, other = np.nan)
col_HADV_zonal_jim = col_HADV_zonal_jim.where(is_valid_ocean_mask, other = np.nan)

col_HADV_meridional = col_HADV_meridional.where(is_valid_ocean_mask, other = np.nan)
col_HADV_meridional_jim = col_HADV_meridional_jim.where(is_valid_ocean_mask, other = np.nan)

# %%
#### Scatter and correlation at some sample locations in Indian Ocean and Pacific ocean ###

lat_tem = 0
lon_tem = 75

data_tem_vijit = col_VADV.sel(lat = lat_tem, lon = lon_tem)
data_tem_jim = col_VADV_jim.sel(lat = lat_tem, lon = lon_tem)

plt.scatter(data_tem_jim, data_tem_vijit)
plt.xlabel('VADV jim')
plt.ylabel('VADV vijit')
plt.title('VADV comparison')

slope, intercept = np.polyfit(data_tem_jim, data_tem_vijit, 1)
plt.plot(data_tem_jim, slope * data_tem_jim + intercept, color='red', label=f'y = {slope:.2f}x + {intercept:.2f}')
plt.plot(data_tem_jim,data_tem_jim,color='grey', label='1:1 line')
plt.legend()

plt.show()

correlation = np.corrcoef(data_tem_jim, data_tem_vijit)[0, 1]
print(f'The correlation is {correlation:.2f}.')

data_tem_vijit = col_HADV.sel(lat = lat_tem, lon = lon_tem)
data_tem_jim = col_HADV_jim.sel(lat = lat_tem, lon = lon_tem)

plt.scatter(data_tem_jim, data_tem_vijit)
plt.xlabel('HADV jim')
plt.ylabel('HADV vijit')
plt.title('HADV comparison')

slope, intercept = np.polyfit(data_tem_jim, data_tem_vijit, 1)
plt.plot(data_tem_jim, slope * data_tem_jim + intercept, color='red', label=f'y = {slope:.2f}x + {intercept:.2f}')
plt.plot(data_tem_jim,data_tem_jim,color='grey', label='1:1 line')
plt.legend()

plt.show()

correlation = np.corrcoef(data_tem_jim, data_tem_vijit)[0, 1]
print(f'The correlation is {correlation:.2f}.')

data_tem_vijit = MSE_tend.sel(lat = lat_tem, lon = lon_tem)
data_tem_jim = MSE_tend_jim.sel(lat = lat_tem, lon = lon_tem)

plt.scatter(data_tem_jim, data_tem_vijit)
plt.xlabel('tend jim')
plt.ylabel('tend vijit')
plt.title('MSE tend comparison')

slope, intercept = np.polyfit(data_tem_jim, data_tem_vijit, 1)
plt.plot(data_tem_jim, slope * data_tem_jim + intercept, color='red', label=f'y = {slope:.2f}x + {intercept:.2f}')
plt.plot(data_tem_jim,data_tem_jim,color='grey', label='1:1 line')
plt.legend()

plt.show()

correlation = np.corrcoef(data_tem_jim, data_tem_vijit)[0, 1]
print(f'The correlation is {correlation:.2f}.')
# Out:
# The correlation is -0.88.
# The correlation is -0.85.
# The correlation is 1.00.

# %%
#### Scatter and correlation at some sample locations in Indian Ocean and Pacific ocean ###

lat_tem = 0
lon_tem = 165

data_tem_vijit = col_VADV.sel(lat = lat_tem, lon = lon_tem)
data_tem_jim = col_VADV_jim.sel(lat = lat_tem, lon = lon_tem)

plt.scatter(data_tem_jim, data_tem_vijit)
plt.xlabel('VADV jim')
plt.ylabel('VADV vijit')
plt.title('VADV comparison')

slope, intercept = np.polyfit(data_tem_jim, data_tem_vijit, 1)
plt.plot(data_tem_jim, slope * data_tem_jim + intercept, color='red', label=f'y = {slope:.2f}x + {intercept:.2f}')
plt.plot(data_tem_jim,data_tem_jim,color='grey', label='1:1 line')
plt.legend()

plt.show()

correlation = np.corrcoef(data_tem_jim, data_tem_vijit)[0, 1]
print(f'The correlation is {correlation:.2f}.')

data_tem_vijit = col_HADV.sel(lat = lat_tem, lon = lon_tem)
data_tem_jim = col_HADV_jim.sel(lat = lat_tem, lon = lon_tem)

plt.scatter(data_tem_jim, data_tem_vijit)
plt.xlabel('HADV jim')
plt.ylabel('HADV vijit')
plt.title('HADV comparison')

slope, intercept = np.polyfit(data_tem_jim, data_tem_vijit, 1)
plt.plot(data_tem_jim, slope * data_tem_jim + intercept, color='red', label=f'y = {slope:.2f}x + {intercept:.2f}')
plt.plot(data_tem_jim,data_tem_jim,color='grey', label='1:1 line')
plt.legend()

plt.show()

correlation = np.corrcoef(data_tem_jim, data_tem_vijit)[0, 1]
print(f'The correlation is {correlation:.2f}.')

data_tem_vijit = MSE_tend.sel(lat = lat_tem, lon = lon_tem)
data_tem_jim = MSE_tend_jim.sel(lat = lat_tem, lon = lon_tem)

plt.scatter(data_tem_jim, data_tem_vijit)
plt.xlabel('tend jim')
plt.ylabel('tend vijit')
plt.title('MSE tend comparison')

slope, intercept = np.polyfit(data_tem_jim, data_tem_vijit, 1)
plt.plot(data_tem_jim, slope * data_tem_jim + intercept, color='red', label=f'y = {slope:.2f}x + {intercept:.2f}')
plt.plot(data_tem_jim,data_tem_jim,color='grey', label='1:1 line')
plt.legend()

plt.show()

correlation = np.corrcoef(data_tem_jim, data_tem_vijit)[0, 1]
print(f'The correlation is {correlation:.2f}.')
# Out:
# The correlation is -0.78.
# The correlation is -0.92.
# The correlation is 1.00.

# %%
#### Scatter and correlation at some sample locations in Indian Ocean and Pacific ocean ###

lat_tem = 5
lon_tem = 180

data_tem_vijit = col_VADV.sel(lat = lat_tem, lon = lon_tem)
data_tem_jim = col_VADV_jim.sel(lat = lat_tem, lon = lon_tem)

plt.scatter(data_tem_jim, data_tem_vijit)
plt.xlabel('VADV jim')
plt.ylabel('VADV vijit')
plt.title('VADV comparison')

slope, intercept = np.polyfit(data_tem_jim, data_tem_vijit, 1)
plt.plot(data_tem_jim, slope * data_tem_jim + intercept, color='red', label=f'y = {slope:.2f}x + {intercept:.2f}')
plt.plot(data_tem_jim,data_tem_jim,color='grey', label='1:1 line')
plt.legend()

plt.show()

correlation = np.corrcoef(data_tem_jim, data_tem_vijit)[0, 1]
print(f'The correlation is {correlation:.2f}.')

data_tem_vijit = col_HADV.sel(lat = lat_tem, lon = lon_tem)
data_tem_jim = col_HADV_jim.sel(lat = lat_tem, lon = lon_tem)

plt.scatter(data_tem_jim, data_tem_vijit)
plt.xlabel('HADV jim')
plt.ylabel('HADV vijit')
plt.title('HADV comparison')

slope, intercept = np.polyfit(data_tem_jim, data_tem_vijit, 1)
plt.plot(data_tem_jim, slope * data_tem_jim + intercept, color='red', label=f'y = {slope:.2f}x + {intercept:.2f}')
plt.plot(data_tem_jim,data_tem_jim,color='grey', label='1:1 line')
plt.legend()

plt.show()

correlation = np.corrcoef(data_tem_jim, data_tem_vijit)[0, 1]
print(f'The correlation is {correlation:.2f}.')

data_tem_vijit = MSE_tend.sel(lat = lat_tem, lon = lon_tem)
data_tem_jim = MSE_tend_jim.sel(lat = lat_tem, lon = lon_tem)

plt.scatter(data_tem_jim, data_tem_vijit)
plt.xlabel('tend jim')
plt.ylabel('tend vijit')
plt.title('MSE tend comparison')

slope, intercept = np.polyfit(data_tem_jim, data_tem_vijit, 1)
plt.plot(data_tem_jim, slope * data_tem_jim + intercept, color='red', label=f'y = {slope:.2f}x + {intercept:.2f}')
plt.plot(data_tem_jim,data_tem_jim,color='grey', label='1:1 line')
plt.legend()

plt.show()

correlation = np.corrcoef(data_tem_jim, data_tem_vijit)[0, 1]
print(f'The correlation is {correlation:.2f}.')
# Out:
# The correlation is -0.68.
# The correlation is -0.93.
# The correlation is 1.00.

# %%
### comparing histograms ###

data_tem_vijit = col_VADV.values.flatten()
data_tem_jim = col_VADV_jim.values.flatten()

plt.hist(data_tem_vijit, bins=20, alpha=0.5, label='vijit')
plt.hist(data_tem_jim, bins=20, alpha=0.5, label='jim')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram - VADV')
plt.legend()

plt.show()


data_tem_vijit = col_HADV.values.flatten()
data_tem_jim = col_HADV_jim.values.flatten()

plt.hist(data_tem_vijit, bins=20, alpha=0.5, label='vijit')
plt.hist(data_tem_jim, bins=20, alpha=0.5, label='jim')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram - HADV')
plt.legend()

plt.show()

data_tem_vijit = MSE_tend.values.flatten()
data_tem_jim = MSE_tend_jim.values.flatten()

plt.hist(data_tem_vijit, bins=20, alpha=0.5, label='vijit')
plt.hist(data_tem_jim, bins=20, alpha=0.5, label='jim')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram - MSE tend')
plt.legend()

plt.show()

# %%
data = col_VADV + col_HADV

time_mean = data.mean(dim='time')
time_max = data.max(dim='time')
time_min = data.min(dim='time')
time_std = data.std(dim='time')

# Plot the spatial maps
fig, axs = plt.subplots(4, 1, figsize=(20, 7), subplot_kw={'projection': ccrs.PlateCarree()})
for ax, data, title in zip(axs, [time_mean, time_max, time_min, time_std], ['Time Mean - diff', 'Maximum - diff', 'Minimum - diff', 'Standard Dev - diff']):
    ax.set_extent([-180, 180, -20, 20], crs=ccrs.PlateCarree())
    data.plot(ax=ax, cmap='coolwarm', transform=ccrs.PlateCarree(), add_colorbar=True, norm=colors.Normalize(vmin = data.min()/2, vmax = data.max()/2), cbar_kwargs={'label': 'col_VADV'})
    ax.add_feature(cfeature.LAND, edgecolor='black')
    ax.set_title(title)

#fig.colorbar(axs[2].collections[0], ax=axs, location='right', shrink=0.6)

plt.show()

################

data = col_VADV_jim + col_HADV_jim

time_mean = data.mean(dim='time')
time_max = data.max(dim='time')
time_min = data.min(dim='time')
time_std = data.std(dim='time')

# Plot the spatial maps
fig, axs = plt.subplots(4, 1, figsize=(20, 7), subplot_kw={'projection': ccrs.PlateCarree()})
for ax, data, title in zip(axs, [time_mean, time_max, time_min, time_std], ['Time Mean - jim', 'Maximum - jim', 'Minimum - jim', 'Standard Dev - jim']):
    ax.set_extent([-180, 180, -20, 20], crs=ccrs.PlateCarree())
    data.plot(ax=ax, cmap='coolwarm', transform=ccrs.PlateCarree(), add_colorbar=True, norm=colors.Normalize(vmin = data.min()/2, vmax = data.max()/2), cbar_kwargs={'label': 'col_VADV'})
    ax.add_feature(cfeature.LAND, edgecolor='black')
    ax.set_title(title)

#fig.colorbar(axs[2].collections[0], ax=axs, location='right', shrink=0.6)

plt.show()

################

# %%
data = col_HADV - col_HADV_jim

time_mean = data.mean(dim='time')
time_max = data.max(dim='time')
time_min = data.min(dim='time')
time_std = data.std(dim='time')

# Plot the spatial maps
fig, axs = plt.subplots(4, 1, figsize=(20, 7), subplot_kw={'projection': ccrs.PlateCarree()})
for ax, data, title in zip(axs, [time_mean, time_max, time_min, time_std], ['Time Mean - diff', 'Maximum - diff', 'Minimum - diff', 'Standard Dev - diff']):
    ax.set_extent([-180, 180, -20, 20], crs=ccrs.PlateCarree())
    data.plot(ax=ax, cmap='coolwarm', transform=ccrs.PlateCarree(), add_colorbar=True, norm=colors.Normalize(vmin = data.min()/2, vmax = data.max()/2), cbar_kwargs={'label': 'col_HADV'})
    ax.add_feature(cfeature.LAND, edgecolor='black')
    ax.set_title(title)

#fig.colorbar(axs[2].collections[0], ax=axs, location='right', shrink=0.6)

plt.show()

################

data = col_HADV_jim

time_mean = data.mean(dim='time')
time_max = data.max(dim='time')
time_min = data.min(dim='time')
time_std = data.std(dim='time')

# Plot the spatial maps
fig, axs = plt.subplots(4, 1, figsize=(20, 7), subplot_kw={'projection': ccrs.PlateCarree()})
for ax, data, title in zip(axs, [time_mean, time_max, time_min, time_std], ['Time Mean - jim', 'Maximum - jim', 'Minimum - jim', 'Standard Dev - jim']):
    ax.set_extent([-180, 180, -20, 20], crs=ccrs.PlateCarree())
    data.plot(ax=ax, cmap='coolwarm', transform=ccrs.PlateCarree(), add_colorbar=True, norm=colors.Normalize(vmin = data.min()/2, vmax = data.max()/2), cbar_kwargs={'label': 'col_HADV'})
    ax.add_feature(cfeature.LAND, edgecolor='black')
    ax.set_title(title)

#fig.colorbar(axs[2].collections[0], ax=axs, location='right', shrink=0.6)

plt.show()

################

# %%
data = MSE_tend - MSE_tend_jim

time_mean = data.mean(dim='time')
time_max = data.max(dim='time')
time_min = data.min(dim='time')
time_std = data.std(dim='time')

# Plot the spatial maps
fig, axs = plt.subplots(4, 1, figsize=(20, 7), subplot_kw={'projection': ccrs.PlateCarree()})
for ax, data, title in zip(axs, [time_mean, time_max, time_min, time_std], ['Time Mean - diff', 'Maximum - diff', 'Minimum - diff', 'Standard Dev - diff']):
    ax.set_extent([-180, 180, -20, 20], crs=ccrs.PlateCarree())
    data.plot(ax=ax, cmap='coolwarm', transform=ccrs.PlateCarree(), add_colorbar=True, norm=colors.Normalize(vmin = data.min()/2, vmax = data.max()/2), cbar_kwargs={'label': 'MSE_tend'})
    ax.add_feature(cfeature.LAND, edgecolor='black')
    ax.set_title(title)

#fig.colorbar(axs[2].collections[0], ax=axs, location='right', shrink=0.6)

plt.show()

################

data = MSE_tend_jim

time_mean = data.mean(dim='time')
time_max = data.max(dim='time')
time_min = data.min(dim='time')
time_std = data.std(dim='time')

# Plot the spatial maps
fig, axs = plt.subplots(4, 1, figsize=(20, 7), subplot_kw={'projection': ccrs.PlateCarree()})
for ax, data, title in zip(axs, [time_mean, time_max, time_min, time_std], ['Time Mean - jim', 'Maximum - jim', 'Minimum - jim', 'Standard Dev - jim']):
    ax.set_extent([-180, 180, -20, 20], crs=ccrs.PlateCarree())
    data.plot(ax=ax, cmap='coolwarm', transform=ccrs.PlateCarree(), add_colorbar=True, norm=colors.Normalize(vmin = data.min()/2, vmax = data.max()/2), cbar_kwargs={'label': 'MSE_tend'})
    ax.add_feature(cfeature.LAND, edgecolor='black')
    ax.set_title(title)

#fig.colorbar(axs[2].collections[0], ax=axs, location='right', shrink=0.6)

plt.show()

################
