# %%
import numpy as np
import xarray as xr
import pandas as pd
#import metpy.calc as mpcalc
from glob import glob
import holoviews as hv
hv.extension('bokeh')
#%matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib.colors import LinearSegmentedColormap

import cartopy.crs as ccrs
import cartopy.feature as cfeature

import sys
sys.path.append('/home/vmaithel')

from tropical_PODs.PODs.POD_utils import limit_files_to_select_years

# Define constants

g = 9.8 #[m s^-2]
L = 2.26e6 #[J/kg]
cp = 1005 #[J/kg-K]
R_e = 6.378e6 #[m]
pi = 22/7
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c7dacd86-cf23-427a-85ef-95a2e3933864" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
def load_in_data(input_file, xarray_name, start_year, end_year, lat_lbound, lat_ubound, upper_level, lower_level):
    
    paths = glob(input_file)
    year_limited_paths = limit_files_to_select_years(paths,range(start_year,end_year+1))
    dataset = xr.open_mfdataset(year_limited_paths, combine="by_coords")
    dataset = dataset.sortby('lat', ascending=True)

    if 'level' in dataset.dims:
        data_var = dataset[xarray_name].sel(time = slice(str(start_year)+'-01-01', str(end_year)+'-12-31'), lat = slice(lat_lbound,lat_ubound), level = slice(upper_level, lower_level))
    else: 
        data_var = dataset[xarray_name].sel(time = slice(str(start_year)+'-01-01', str(end_year)+'-12-31'), lat = slice(lat_lbound,lat_ubound))

    data_var.load()

    return dataset, data_var

# %%
# Years to analyze
start_year = (2010)
end_year = (2011)

lat_lbound = -15 
lat_ubound = 15

upper_level = 100
lower_level = 1000

################
###.  VIJIT MSE budget calculations  ###
################

input_dir = '/home/vmaithel/MSE_budgets/2p5_vijit/'


input_file_MSE = input_dir+'MSE.*.nc' 
input_file_VADV = input_dir+'VADV.*.nc' 
input_file_HADV = input_dir+'HADV.*.nc' 
input_file_HADV_zonal = input_dir+'HADV_zonal.*.nc'  
input_file_HADV_meridional = input_dir+'HADV_meridional.*.nc' 


dataset_MSE, MSE = load_in_data(input_file_MSE,'MSE',start_year, end_year, lat_lbound, lat_ubound, upper_level, lower_level)
dataset_VADV, VADV = load_in_data(input_file_VADV,'VADV',start_year, end_year, lat_lbound, lat_ubound,  upper_level, lower_level)
dataset_HADV, HADV = load_in_data(input_file_HADV,'HADV',start_year, end_year, lat_lbound, lat_ubound,  upper_level, lower_level)
dataset_HADV_zonal, HADV_zonal = load_in_data(input_file_HADV_zonal,'HADV_zonal',start_year, end_year, lat_lbound, lat_ubound,  upper_level, lower_level)
dataset_HADV_meridional, HADV_meridional = load_in_data(input_file_HADV_meridional,'HADV_meridional',start_year, end_year, lat_lbound, lat_ubound,  upper_level, lower_level)

################
###.  JIM MSE budget calculations  ###
################

input_file_jim_col_budget = '/Projects/era5_regrid/2p5_benedict/ERA5_2.5deg_daily/ERA5.MSEviBudget.*.nc'
input_file_jim_VADV = '/Projects/era5_regrid/2p5_benedict/ERA5_2.5deg_daily/MSEvert.2p5.*.daily.nc'
input_file_jim_HADV = '/Projects/era5_regrid/2p5_benedict/ERA5_2.5deg_daily/MSEhoriz.2p5.*.daily.nc'

dataset_jim_VADV, VADV_jim = load_in_data(input_file_jim_VADV,'WDMDP', start_year, end_year, lat_lbound, lat_ubound,  upper_level, lower_level)
dataset_jim_HADV, HADV_jim = load_in_data(input_file_jim_HADV,'VDOTDELM', start_year, end_year, lat_lbound, lat_ubound,  upper_level, lower_level)
dataset_jim_HADV_zonal, HADV_zonal_jim = load_in_data(input_file_jim_HADV,'UDMDX', start_year, end_year, lat_lbound, lat_ubound,  upper_level, lower_level)


HADV_meridional_jim = HADV_jim - HADV_zonal_jim

# %%
print(VADV)
# Out:
# <xarray.DataArray 'VADV' (time: 730, level: 27, lat: 13, lon: 144)>
# array([[[[-1.06156571e-02,  1.97789678e-03, -2.96913497e-02, ...,
#           -1.53999757e-02, -2.43821908e-02, -2.85515562e-03],
#          [-2.98030470e-02, -2.25255662e-03, -2.31546406e-02, ...,
#            7.17984233e-03,  8.38190317e-03, -3.64539288e-02],
#          [-1.39179137e-02, -5.87954000e-03, -1.35308113e-02, ...,
#           -5.23143797e-04, -1.38538089e-02, -2.00317148e-02],
#          ...,
#          [-1.08332690e-02, -3.29111866e-03, -1.60571672e-02, ...,
#           -1.71373151e-02, -1.59173142e-02, -9.77856293e-03],
#          [-1.83462612e-02, -2.04216819e-02, -6.59698714e-03, ...,
#           -2.03433586e-03, -1.32688181e-02, -1.79826673e-02],
#          [-1.15716141e-02, -1.54663865e-02, -1.20675657e-02, ...,
#            3.56117752e-03,  5.42993518e-03,  6.77576056e-04]],
#
#         [[ 1.54196732e-02, -4.51214425e-02,  1.94218438e-02, ...,
# ...

# %%
### comparing histograms ###

data_vijit = VADV
data_jim = VADV_jim

plt.plot(data_vijit[45,:,7,35],data_vijit.level,label='vijit')
plt.plot(-data_jim[45,:,7,35],data_jim.level,label='jim')
plt.xlabel('VADV')
plt.ylabel('level')
plt.title('VADV profile')
plt.legend()

plt.show()

plt.plot(data_vijit[145,:,7,35],data_vijit.level,label='vijit')
plt.plot(-data_jim[145,:,7,35],data_jim.level,label='jim')
plt.xlabel('VADV')
plt.ylabel('level')
plt.title('VADV profile')
plt.legend()

plt.show()

plt.plot(data_vijit[45,:,7,72],data_vijit.level,label='vijit')
plt.plot(-data_jim[45,:,7,72],data_jim.level,label='jim')
plt.xlabel('VADV')
plt.ylabel('level')
plt.title('VADV profile')
plt.legend()

plt.show()

# %%
### comparing histograms ###

data_vijit = HADV
data_jim = HADV_jim

plt.plot(data_vijit[45,:,7,35],data_vijit.level,label='vijit')
plt.plot(-data_jim[45,:,7,35],data_jim.level,label='jim')
plt.xlabel('HADV')
plt.ylabel('level')
plt.title('HADV profile')
plt.legend()

plt.show()

plt.plot(data_vijit[145,:,7,35],data_vijit.level,label='vijit')
plt.plot(-data_jim[145,:,7,35],data_jim.level,label='jim')
plt.xlabel('HADV')
plt.ylabel('level')
plt.title('HADV profile')
plt.legend()

plt.show()

plt.plot(data_vijit[45,:,7,72],data_vijit.level,label='vijit')
plt.plot(-data_jim[45,:,7,72],data_jim.level,label='jim')
plt.xlabel('HADV')
plt.ylabel('level')
plt.title('HADV profile')
plt.legend()

plt.show()

# %%
### comparing histograms ###

data_vijit = HADV_zonal
data_jim = HADV_zonal_jim

plt.plot(data_vijit[45,:,7,35],data_vijit.level,label='vijit')
plt.plot(-data_jim[45,:,7,35],data_jim.level,label='jim')
plt.xlabel('HADV')
plt.ylabel('level')
plt.title('HADV zonal profile')
plt.legend()

plt.show()

plt.plot(data_vijit[145,:,7,35],data_vijit.level,label='vijit')
plt.plot(-data_jim[145,:,7,35],data_jim.level,label='jim')
plt.xlabel('HADV')
plt.ylabel('level')
plt.title('HADV zonal profile')
plt.legend()

plt.show()

plt.plot(data_vijit[45,:,7,72],data_vijit.level,label='vijit')
plt.plot(-data_jim[45,:,7,72],data_jim.level,label='jim')
plt.xlabel('HADV')
plt.ylabel('level')
plt.title('HADV zonal profile')
plt.legend()

plt.show()

# %%
### comparing histograms ###

data_vijit = HADV_meridional
data_jim = HADV_meridional_jim

plt.plot(data_vijit[45,:,7,35],data_vijit.level,label='vijit')
plt.plot(-data_jim[45,:,7,35],data_jim.level,label='jim')
plt.xlabel('HADV')
plt.ylabel('level')
plt.title('HADV meridional profile')
plt.legend()

plt.show()

plt.plot(data_vijit[145,:,7,35],data_vijit.level,label='vijit')
plt.plot(-data_jim[145,:,7,35],data_jim.level,label='jim')
plt.xlabel('HADV')
plt.ylabel('level')
plt.title('HADV meridional profile')
plt.legend()

plt.show()

plt.plot(data_vijit[45,:,7,72],data_vijit.level,label='vijit')
plt.plot(-data_jim[45,:,7,72],data_jim.level,label='jim')
plt.xlabel('HADV')
plt.ylabel('level')
plt.title('HADV meridional profile')
plt.legend()

plt.show()

# %%
VADV_diff = VADV + VADV_jim
HADV_diff = HADV + HADV_jim

VADV_diff_var = VADV_diff.var(dim='time')
HADV_diff_var = HADV_diff.var(dim='time')

VADV_diff_mean = VADV_diff.mean(dim='time')
HADV_diff_mean = HADV_diff.mean(dim='time')


data = VADV_diff_var

plt.plot(data[:,7,35],data.level,label='loc1')
plt.plot(data[:,7,72],data.level,label='loc2')
plt.plot(data[:,7,92],data.level,label='loc3')
plt.xlabel('VADV diff var')
plt.ylabel('level')
plt.title('VADV diff variance profile')
plt.legend()
plt.show()


data = HADV_diff_var

plt.plot(data[:,7,35],data.level,label='loc1')
plt.plot(data[:,7,72],data.level,label='loc2')
plt.plot(data[:,7,92],data.level,label='loc3')
plt.xlabel('HADV diff var')
plt.ylabel('level')
plt.title('HADV diff variance profile')
plt.legend()
plt.show()

print(data.lat[7], data.lon[35])
print(data.lon[72])
print(data.lon[92])
# Out:
# <xarray.DataArray 'lat' ()>
# array(2.5, dtype=float32)
# Coordinates:
#     lat      float32 2.5
# Attributes:
#     long_name:  latitude
#     units:      degrees_north <xarray.DataArray 'lon' ()>
# array(87.5, dtype=float32)
# Coordinates:
#     lon      float32 87.5
# Attributes:
#     long_name:  longitude
#     units:      degrees_east
# <xarray.DataArray 'lon' ()>
# array(180., dtype=float32)
# Coordinates:
#     lon      float32 180.0
# Attributes:
#     long_name:  longitude
#     units:      degrees_east
# <xarray.DataArray 'lon' ()>
# array(230., dtype=float32)
# Coordinates:
#     lon      float32 230.0
# Attributes:
#     long_name:  longitude
#     units:      degrees_east

# %%
data = VADV_diff_mean

plt.plot(data[:,7,35],data.level,label='loc1')
plt.plot(data[:,7,72],data.level,label='loc2')
plt.plot(data[:,7,92],data.level,label='loc3')
plt.xlabel('VADV diff mean')
plt.ylabel('level')
plt.title('VADV diff mean profile')
plt.legend()
plt.show()


data = HADV_diff_mean

plt.plot(data[:,7,35],data.level,label='loc1')
plt.plot(data[:,7,72],data.level,label='loc2')
plt.plot(data[:,7,92],data.level,label='loc3')
plt.xlabel('HADV diff mean')
plt.ylabel('level')
plt.title('HADV diff mean profile')
plt.legend()
plt.show()
